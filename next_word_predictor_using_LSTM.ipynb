# %%
faqs = """Introduction to C++ Programming Language
Last Updated : 11 Oct, 2024
C++ is a general-purpose programming language that was developed as an enhancement of the C language to include object-oriented paradigm. It is an imperative and a compiled language.

C++ is a high-level, general-purpose programming language designed for system and application programming. It was developed by Bjarne Stroustrup at Bell Labs in 1983 as an extension of the C programming language. C++ is an object-oriented, multi-paradigm language that supports procedural, functional, and generic programming styles.
One of the key features of C++ is its ability to support low-level, system-level programming, making it suitable for developing operating systems, device drivers, and other system software. At the same time, C++ also provides a rich set of libraries and features for high-level application programming, making it a popular choice for developing desktop applications, video games, and other complex applications.
C++ has a large, active community of developers and users, and a wealth of resources and tools available for learning and using the language. Some of the key features of C++ include:
Object-Oriented Programming: C++ supports object-oriented programming, allowing developers to create classes and objects and to define methods and properties for these objects.
Templates: C++ templates allow developers to write generic code that can work with any data type, making it easier to write reusable and flexible code.
Standard Template Library (STL): The STL provides a wide range of containers and algorithms for working with data, making it easier to write efficient and effective code.
Exception Handling: C++ provides robust exception handling capabilities, making it easier to write code that can handle errors and unexpected situations.
Overall, C++ is a powerful and versatile programming language that is widely used for a range of applications and is well-suited for both low-level system programming and high-level application development. If you wish to learn C++ then you can enroll in our C++ Course provides a comprehensive introduction to the C++ programming language, covering its fundamentals and best practices.

C++ is a middle-level language rendering it the advantage of programming low-level (drivers, kernels) and even higher-level applications (games, GUI, desktop apps etc.). The basic syntax and code structure of both C and C++ are the same.
Some of the features & key-points to note about the programming language are as follows:

Simple: It is a simple language in the sense that programs can be broken down into logical units and parts, has a rich library support and a variety of data-types.
Machine Independent but Platform Dependent: A C++ executable is not platform-independent (compiled programs on Linux won’t run on Windows), however they are machine independent.
Mid-level language: It is a mid-level language as we can do both systems-programming (drivers, kernels, networking etc.) and build large-scale user applications (Media Players, Photoshop, Game Engines etc.)
Rich library support: Has a rich library support (Both standard ~ built-in data structures, algorithms etc.) as well 3rd party libraries (e.g. Boost libraries) for fast and rapid development.
Speed of execution: C++ programs excel in execution speed. Since, it is a compiled language, and also hugely procedural. Newer languages have extra in-built default features such as garbage-collection, dynamic typing etc. which slow the execution of the program overall. Since there is no additional processing overhead like this in C++, it is blazing fast.
Pointer and direct Memory-Access: C++ provides pointer support which aids users to directly manipulate storage address. This helps in doing low-level programming (where one might need to have explicit control on the storage of variables).
Object-Oriented: One of the strongest points of the language which sets it apart from C. Object-Oriented support helps C++ to make maintainable and extensible programs. i.e. Large-scale applications can be built. Procedural code becomes difficult to maintain as code-size grows.
Compiled Language: C++ is a compiled language, contributing to its speed.
Here are some key points to keep in mind while working with C++:
Object-Oriented Programming: C++ is an object-oriented programming language, which means that it allows you to define classes and objects to model real-world entities and their behavior.
Strong Type System: C++ has a strong type system, which means that variables have a specific type and that type must be respected in all operations performed on that variable.
Low-level Access: C++ provides low-level access to system resources, which makes it a suitable choice for system programming and writing efficient code.
Standard Template Library (STL): The STL provides a large set of pre-written algorithms and data structures that can be used to simplify your code and make it more efficient.
Cross-platform Compatibility: C++ can be compiled and run on multiple platforms, including Windows, MacOS, and Linux, making it a versatile language for developing cross-platform applications.
Performance: C++ is a compiled language, which means that code is transformed into machine code before it is executed. This can result in faster execution times and improved performance compared to interpreted languages like Python.
Memory Management: C++ requires manual memory management, which can lead to errors if not done correctly. However, this also provides more control over the program’s memory usage and can result in more efficient memory usage.
Syntax: C++ has a complex syntax that can be difficult to learn, especially for beginners. However, with practice and experience, it becomes easier to understand and work with.
These are some of the key points to keep in mind when working with C++. By understanding these concepts, you can make informed decisions and write effective code in this language.

Applications of C++:
C++ finds varied usage in applications such as:

Operating Systems & Systems Programming. e.g. Linux-based OS (Ubuntu etc.)
Browsers (Chrome & Firefox)
Graphics & Game engines (Photoshop, Blender, Unreal-Engine)
Database Engines (MySQL, MongoDB, Redis etc.)
Cloud/Distributed Systems
Advantages of C++:
Performance: C++ is a compiled language, which means that its code is compiled into machine-readable code, making it one of the fastest programming languages.
Object-Oriented Programming: C++ supports object-oriented programming, which makes it easier to write and maintain large, complex applications.
Standard Template Library (STL): The STL provides a wide range of algorithms and data structures for working with data, making it easier to write efficient and effective code.
Machine Independent: C++ is not tied to any hardware or processor. If the compiler compiles the program in the system, it will be able to run no matter what the hardware is.
Large Community: C++ has a large, active community of developers and users, providing a wealth of resources and support for learning and using the language.
Disadvantages of C++:
Steep Learning Curve: C++ can be challenging to learn, especially for beginners, due to its complexity and the number of concepts that need to be understood.
Verbose Syntax: C++ has a verbose syntax, which can make code longer and more difficult to read and maintain.
Error-Prone: C++ provides low-level access to system resources, which can lead to subtle errors that are difficult to detect and fix.
Some interesting facts about C++:
Here are some awesome facts about C++ that may interest you:

The name of C++ signifies the evolutionary nature of the changes from C. “++” is the C increment operator.
C++ is one of the predominant languages for the development of all kind of technical and commercial software.
C++ introduces Object-Oriented Programming, not present in C. Like other things, C++ supports the four primary features of OOP: encapsulation, polymorphism, abstraction, and inheritance.
C++ got the OOP features from Simula67 Programming language.
A function is a minimum requirement for a C++ program to run.(at least main() function)
Reference Books:
“The C++ Programming Language” by Bjarne Stroustrup
“Effective C++: 55 Specific Ways to Improve Your Programs and Designs” by Scott Meyers
“C++ Primer Plus” by Stephen Prata
“C++ For Dummies” by Stephen R. Davis
“Data Structures and Algorithm Analysis in C++” by Mark Allen Weiss
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
tokenizer.index_word
# Out:
# {1: 'c',
#  2: 'and',
#  3: 'to',
#  4: 'the',
#  5: 'of',
#  6: 'a',
#  7: 'programming',
#  8: 'is',
#  9: 'language',
#  10: 'it',
#  11: 'for',
#  12: 'in',
#  13: 'that',
#  14: 'code',
#  15: 'can',
#  16: 'level',
#  17: 'which',
#  18: 'object',
#  19: 'oriented',
#  20: 'system',
#  21: 'provides',
#  22: 'applications',
#  23: 'compiled',
#  24: 'be',
#  25: 'as',
#  26: 'making',
#  27: 'by',
#  28: 'features',
#  29: 'support',
#  30: 'low',
#  31: 'has',
#  32: 'large',
#  33: 'write',
#  34: 'with',
#  35: 'data',
#  36: 'etc',
#  37: 'are',
#  38: 'some',
#  39: 'easier',
#  40: 'library',
#  41: 'stl',
#  42: 'an',
#  43: 'one',
#  44: 'key',
#  45: 'its',
#  46: 'systems',
#  47: 'type',
#  48: 'efficient',
#  49: 'you',
#  50: 'syntax',
#  51: 'programs',
#  52: 'machine',
#  53: 'on',
#  54: 'this',
#  55: 'memory',
#  56: 'supports',
#  57: 'rich',
#  58: 'developers',
#  59: 'resources',
#  60: 'standard',
#  61: 'algorithms',
#  62: 'working',
#  63: 'both',
#  64: 'points',
#  65: 'independent',
#  66: 'platform',
#  67: 'not',
#  68: 'run',
#  69: 'structures',
#  70: 'execution',
#  71: 'languages',
#  72: 'access',
#  73: 'make',
#  74: 'difficult',
#  75: 'means',
#  76: 'more',
#  77: 'high',
#  78: 'application',
#  79: 'at',
#  80: 'procedural',
#  81: 'developing',
#  82: 'drivers',
#  83: 'other',
#  84: 'also',
#  85: 'libraries',
#  86: 'complex',
#  87: 'community',
#  88: 'users',
#  89: 'learning',
#  90: 'objects',
#  91: 'these',
#  92: 'template',
#  93: 'range',
#  94: 'effective',
#  95: 'errors',
#  96: 'development',
#  97: 'if',
#  98: 'learn',
#  99: 'about',
#  100: 'into',
#  101: 'linux',
#  102: 'however',
#  103: 'engines',
#  104: 'built',
#  105: 'e',
#  106: 'speed',
#  107: 'have',
#  108: 'program',
#  109: 'like',
#  110: 'from',
#  111: 'maintain',
#  112: 'performance',
#  113: 'usage',
#  114: 'introduction',
#  115: 'general',
#  116: 'purpose',
#  117: 'was',
#  118: 'developed',
#  119: 'include',
#  120: 'paradigm',
#  121: 'bjarne',
#  122: 'stroustrup',
#  123: 'generic',
#  124: 'suitable',
#  125: 'operating',
#  126: 'software',
#  127: 'same',
#  128: 'set',
#  129: 'choice',
#  130: 'desktop',
#  131: 'games',
#  132: 'active',
#  133: 'wealth',
#  134: 'using',
#  135: 'classes',
#  136: 'define',
#  137: 'templates',
#  138: 'work',
#  139: 'any',
#  140: 'wide',
#  141: 'exception',
#  142: 'handling',
#  143: 'overall',
#  144: 'versatile',
#  145: 'used',
#  146: 'well',
#  147: 'kernels',
#  148: 'simple',
#  149: 'windows',
#  150: 'mid',
#  151: 'scale',
#  152: 'photoshop',
#  153: 'game',
#  154: 'g',
#  155: 'fast',
#  156: 'since',
#  157: 'such',
#  158: 'no',
#  159: 'pointer',
#  160: 'storage',
#  161: 'helps',
#  162: 'need',
#  163: 'control',
#  164: 'variables',
#  165: 'becomes',
#  166: 'here',
#  167: 'keep',
#  168: 'mind',
#  169: 'strong',
#  170: 'specific',
#  171: 'all',
#  172: 'makes',
#  173: 'your',
#  174: 'cross',
#  175: 'result',
#  176: 'management',
#  177: 'lead',
#  178: 'especially',
#  179: 'beginners',
#  180: 'concepts',
#  181: 'hardware',
#  182: 'verbose',
#  183: 'facts',
#  184: '”',
#  185: 'oop',
#  186: 'function',
#  187: '“c',
#  188: 'stephen',
#  189: 'last',
#  190: 'updated',
#  191: '11',
#  192: 'oct',
#  193: '2024',
#  194: 'enhancement',
#  195: 'imperative',
#  196: 'designed',
#  197: 'bell',
#  198: 'labs',
#  199: '1983',
#  200: 'extension',
#  201: 'multi',
#  202: 'functional',
#  203: 'styles',
#  204: 'ability',
#  205: 'device',
#  206: 'time',
#  207: 'popular',
#  208: 'video',
#  209: 'tools',
#  210: 'available',
#  211: 'allowing',
#  212: 'create',
#  213: 'methods',
#  214: 'properties',
#  215: 'allow',
#  216: 'reusable',
#  217: 'flexible',
#  218: 'containers',
#  219: 'robust',
#  220: 'capabilities',
#  221: 'handle',
#  222: 'unexpected',
#  223: 'situations',
#  224: 'powerful',
#  225: 'widely',
#  226: 'suited',
#  227: 'wish',
#  228: 'then',
#  229: 'enroll',
#  230: 'our',
#  231: 'course',
#  232: 'comprehensive',
#  233: 'covering',
#  234: 'fundamentals',
#  235: 'best',
#  236: 'practices',
#  237: 'middle',
#  238: 'rendering',
#  239: 'advantage',
#  240: 'even',
#  241: 'higher',
#  242: 'gui',
#  243: 'apps',
#  244: 'basic',
#  245: 'structure',
#  246: 'note',
#  247: 'follows',
#  248: 'sense',
#  249: 'broken',
#  250: 'down',
#  251: 'logical',
#  252: 'units',
#  253: 'parts',
#  254: 'variety',
#  255: 'types',
#  256: 'but',
#  257: 'dependent',
#  258: 'executable',
#  259: 'won’t',
#  260: 'they',
#  261: 'we',
#  262: 'do',
#  263: 'networking',
#  264: 'build',
#  265: 'user',
#  266: 'media',
#  267: 'players',
#  268: '3rd',
#  269: 'party',
#  270: 'boost',
#  271: 'rapid',
#  272: 'excel',
#  273: 'hugely',
#  274: 'newer',
#  275: 'extra',
#  276: 'default',
#  277: 'garbage',
#  278: 'collection',
#  279: 'dynamic',
#  280: 'typing',
#  281: 'slow',
#  282: 'there',
#  283: 'additional',
#  284: 'processing',
#  285: 'overhead',
#  286: 'blazing',
#  287: 'direct',
#  288: 'aids',
#  289: 'directly',
#  290: 'manipulate',
#  291: 'address',
#  292: 'doing',
#  293: 'where',
#  294: 'might',
#  295: 'explicit',
#  296: 'strongest',
#  297: 'sets',
#  298: 'apart',
#  299: 'maintainable',
#  300: 'extensible',
#  301: 'i',
#  302: 'size',
#  303: 'grows',
#  304: 'contributing',
#  305: 'while',
#  306: 'allows',
#  307: 'model',
#  308: 'real',
#  309: 'world',
#  310: 'entities',
#  311: 'their',
#  312: 'behavior',
#  313: 'must',
#  314: 'respected',
#  315: 'operations',
#  316: 'performed',
#  317: 'variable',
#  318: 'writing',
#  319: 'pre',
#  320: 'written',
#  321: 'simplify',
#  322: 'compatibility',
#  323: 'multiple',
#  324: 'platforms',
#  325: 'including',
#  326: 'macos',
#  327: 'transformed',
#  328: 'before',
#  329: 'executed',
#  330: 'faster',
#  331: 'times',
#  332: 'improved',
#  333: 'compared',
#  334: 'interpreted',
#  335: 'python',
#  336: 'requires',
#  337: 'manual',
#  338: 'done',
#  339: 'correctly',
#  340: 'over',
#  341: 'program’s',
#  342: 'practice',
#  343: 'experience',
#  344: 'understand',
#  345: 'when',
#  346: 'understanding',
#  347: 'informed',
#  348: 'decisions',
#  349: 'finds',
#  350: 'varied',
#  351: 'based',
#  352: 'os',
#  353: 'ubuntu',
#  354: 'browsers',
#  355: 'chrome',
#  356: 'firefox',
#  357: 'graphics',
#  358: 'blender',
#  359: 'unreal',
#  360: 'engine',
#  361: 'database',
#  362: 'mysql',
#  363: 'mongodb',
#  364: 'redis',
#  365: 'cloud',
#  366: 'distributed',
#  367: 'advantages',
#  368: 'readable',
#  369: 'fastest',
#  370: 'tied',
#  371: 'or',
#  372: 'processor',
#  373: 'compiler',
#  374: 'compiles',
#  375: 'will',
#  376: 'able',
#  377: 'matter',
#  378: 'what',
#  379: 'providing',
#  380: 'disadvantages',
#  381: 'steep',
#  382: 'curve',
#  383: 'challenging',
#  384: 'due',
#  385: 'complexity',
#  386: 'number',
#  387: 'understood',
#  388: 'longer',
#  389: 'read',
#  390: 'error',
#  391: 'prone',
#  392: 'subtle',
#  393: 'detect',
#  394: 'fix',
#  395: 'interesting',
#  396: 'awesome',
#  397: 'may',
#  398: 'interest',
#  399: 'name',
#  400: 'signifies',
#  401: 'evolutionary',
#  402: 'nature',
#  403: 'changes',
#  404: '“',
#  405: 'increment',
#  406: 'operator',
#  407: 'predominant',
#  408: 'kind',
#  409: 'technical',
#  410: 'commercial',
#  411: 'introduces',
#  412: 'present',
#  413: 'things',
#  414: 'four',
#  415: 'primary',
#  416: 'encapsulation',
#  417: 'polymorphism',
#  418: 'abstraction',
#  419: 'inheritance',
#  420: 'got',
#  421: 'simula67',
#  422: 'minimum',
#  423: 'requirement',
#  424: 'least',
#  425: 'main',
#  426: 'reference',
#  427: 'books',
#  428: '“the',
#  429: 'language”',
#  430: '“effective',
#  431: '55',
#  432: 'ways',
#  433: 'improve',
#  434: 'designs”',
#  435: 'scott',
#  436: 'meyers',
#  437: 'primer',
#  438: 'plus”',
#  439: 'prata',
#  440: 'dummies”',
#  441: 'r',
#  442: 'davis',
#  443: '“data',
#  444: 'algorithm',
#  445: 'analysis',
#  446: 'mark',
#  447: 'allen',
#  448: 'weiss'}

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1, len(tokenized_sentence)):
    n_gram = tokenized_sentence[:i+1]
    input_sequences.append(n_gram)

# %%
input_sequences
# Out:
# [[114, 3],
#  [114, 3, 1],
#  [114, 3, 1, 7],
#  [114, 3, 1, 7, 9],
#  [189, 190],
#  [189, 190, 191],
#  [189, 190, 191, 192],
#  [189, 190, 191, 192, 193],
#  [1, 8],
#  [1, 8, 6],
#  [1, 8, 6, 115],
#  [1, 8, 6, 115, 116],
#  [1, 8, 6, 115, 116, 7],
#  [1, 8, 6, 115, 116, 7, 9],
#  [1, 8, 6, 115, 116, 7, 9, 13],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42, 194],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42, 194, 5],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42, 194, 5, 4],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42, 194, 5, 4, 1],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42, 194, 5, 4, 1, 9],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42, 194, 5, 4, 1, 9, 3],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42, 194, 5, 4, 1, 9, 3, 119],
#  [1, 8, 6, 115, 116, 7, 9, 13, 117, 118, 25, 42, 194, 5, 4, 1, 9, 3, 119, 18],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120,
#   10],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120,
#   10,
#   8],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120,
#   10,
#   8,
#   42],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120,
#   10,
#   8,
#   42,
#   195],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120,
#   10,
#   8,
#   42,
#   195,
#   2],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120,
#   10,
#   8,
#   42,
#   195,
#   2,
#   6],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120,
#   10,
#   8,
#   42,
#   195,
#   2,
#   6,
#   23],
#  [1,
#   8,
#   6,
#   115,
#   116,
#   7,
#   9,
#   13,
#   117,
#   118,
#   25,
#   42,
#   194,
#   5,
#   4,
#   1,
#   9,
#   3,
#   119,
#   18,
#   19,
#   120,
#   10,
#   8,
#   42,
#   195,
#   2,
#   6,
#   23,
#   9],
#  [1, 8],
#  [1, 8, 6],
#  [1, 8, 6, 77],
#  [1, 8, 6, 77, 16],
#  [1, 8, 6, 77, 16, 115],
#  [1, 8, 6, 77, 16, 115, 116],
#  [1, 8, 6, 77, 16, 115, 116, 7],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11, 20],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11, 20, 2],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11, 20, 2, 78],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11, 20, 2, 78, 7],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11, 20, 2, 78, 7, 10],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11, 20, 2, 78, 7, 10, 117],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11, 20, 2, 78, 7, 10, 117, 118],
#  [1, 8, 6, 77, 16, 115, 116, 7, 9, 196, 11, 20, 2, 78, 7, 10, 117, 118, 27],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9,
#   13],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9,
#   13,
#   56],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9,
#   13,
#   56,
#   80],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9,
#   13,
#   56,
#   80,
#   202],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9,
#   13,
#   56,
#   80,
#   202,
#   2],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9,
#   13,
#   56,
#   80,
#   202,
#   2,
#   123],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9,
#   13,
#   56,
#   80,
#   202,
#   2,
#   123,
#   7],
#  [1,
#   8,
#   6,
#   77,
#   16,
#   115,
#   116,
#   7,
#   9,
#   196,
#   11,
#   20,
#   2,
#   78,
#   7,
#   10,
#   117,
#   118,
#   27,
#   121,
#   122,
#   79,
#   197,
#   198,
#   12,
#   199,
#   25,
#   42,
#   200,
#   5,
#   4,
#   1,
#   7,
#   9,
#   1,
#   8,
#   42,
#   18,
#   19,
#   201,
#   120,
#   9,
#   13,
#   56,
#   80,
#   202,
#   2,
#   123,
#   7,
#   203],
#  [43, 5],
#  [43, 5, 4],
#  [43, 5, 4, 44],
#  [43, 5, 4, 44, 28],
#  [43, 5, 4, 44, 28, 5],
#  [43, 5, 4, 44, 28, 5, 1],
#  [43, 5, 4, 44, 28, 5, 1, 8],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29, 30],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29, 30, 16],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29, 30, 16, 20],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29, 30, 16, 20, 16],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29, 30, 16, 20, 16, 7],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29, 30, 16, 20, 16, 7, 26],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29, 30, 16, 20, 16, 7, 26, 10],
#  [43, 5, 4, 44, 28, 5, 1, 8, 45, 204, 3, 29, 30, 16, 20, 16, 7, 26, 10, 124],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81,
#   130],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81,
#   130,
#   22],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81,
#   130,
#   22,
#   208],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81,
#   130,
#   22,
#   208,
#   131],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81,
#   130,
#   22,
#   208,
#   131,
#   2],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81,
#   130,
#   22,
#   208,
#   131,
#   2,
#   83],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81,
#   130,
#   22,
#   208,
#   131,
#   2,
#   83,
#   86],
#  [43,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   8,
#   45,
#   204,
#   3,
#   29,
#   30,
#   16,
#   20,
#   16,
#   7,
#   26,
#   10,
#   124,
#   11,
#   81,
#   125,
#   46,
#   205,
#   82,
#   2,
#   83,
#   20,
#   126,
#   79,
#   4,
#   127,
#   206,
#   1,
#   84,
#   21,
#   6,
#   57,
#   128,
#   5,
#   85,
#   2,
#   28,
#   11,
#   77,
#   16,
#   78,
#   7,
#   26,
#   10,
#   6,
#   207,
#   129,
#   11,
#   81,
#   130,
#   22,
#   208,
#   131,
#   2,
#   83,
#   86,
#   22],
#  [1, 31],
#  [1, 31, 6],
#  [1, 31, 6, 32],
#  [1, 31, 6, 32, 132],
#  [1, 31, 6, 32, 132, 87],
#  [1, 31, 6, 32, 132, 87, 5],
#  [1, 31, 6, 32, 132, 87, 5, 58],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6, 133],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6, 133, 5],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6, 133, 5, 59],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6, 133, 5, 59, 2],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6, 133, 5, 59, 2, 209],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6, 133, 5, 59, 2, 209, 210],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6, 133, 5, 59, 2, 209, 210, 11],
#  [1, 31, 6, 32, 132, 87, 5, 58, 2, 88, 2, 6, 133, 5, 59, 2, 209, 210, 11, 89],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9,
#   38],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9,
#   38,
#   5],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9,
#   38,
#   5,
#   4],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9,
#   38,
#   5,
#   4,
#   44],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9,
#   38,
#   5,
#   4,
#   44,
#   28],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9,
#   38,
#   5,
#   4,
#   44,
#   28,
#   5],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9,
#   38,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1],
#  [1,
#   31,
#   6,
#   32,
#   132,
#   87,
#   5,
#   58,
#   2,
#   88,
#   2,
#   6,
#   133,
#   5,
#   59,
#   2,
#   209,
#   210,
#   11,
#   89,
#   2,
#   134,
#   4,
#   9,
#   38,
#   5,
#   4,
#   44,
#   28,
#   5,
#   1,
#   119],
#  [18, 19],
#  [18, 19, 7],
#  [18, 19, 7, 1],
#  [18, 19, 7, 1, 56],
#  [18, 19, 7, 1, 56, 18],
#  [18, 19, 7, 1, 56, 18, 19],
#  [18, 19, 7, 1, 56, 18, 19, 7],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212, 135],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212, 135, 2],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212, 135, 2, 90],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212, 135, 2, 90, 2],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212, 135, 2, 90, 2, 3],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212, 135, 2, 90, 2, 3, 136],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212, 135, 2, 90, 2, 3, 136, 213],
#  [18, 19, 7, 1, 56, 18, 19, 7, 211, 58, 3, 212, 135, 2, 90, 2, 3, 136, 213, 2],
#  [18,
#   19,
#   7,
#   1,
#   56,
#   18,
#   19,
#   7,
#   211,
#   58,
#   3,
#   212,
#   135,
#   2,
#   90,
#   2,
#   3,
#   136,
#   213,
#   2,
#   214],
#  [18,
#   19,
#   7,
#   1,
#   56,
#   18,
#   19,
#   7,
#   211,
#   58,
#   3,
#   212,
#   135,
#   2,
#   90,
#   2,
#   3,
#   136,
#   213,
#   2,
#   214,
#   11],
#  [18,
#   19,
#   7,
#   1,
#   56,
#   18,
#   19,
#   7,
#   211,
#   58,
#   3,
#   212,
#   135,
#   2,
#   90,
#   2,
#   3,
#   136,
#   213,
#   2,
#   214,
#   11,
#   91],
#  [18,
#   19,
#   7,
#   1,
#   56,
#   18,
#   19,
#   7,
#   211,
#   58,
#   3,
#   212,
#   135,
#   2,
#   90,
#   2,
#   3,
#   136,
#   213,
#   2,
#   214,
#   11,
#   91,
#   90],
#  [137, 1],
#  [137, 1, 137],
#  [137, 1, 137, 215],
#  [137, 1, 137, 215, 58],
#  [137, 1, 137, 215, 58, 3],
#  [137, 1, 137, 215, 58, 3, 33],
#  [137, 1, 137, 215, 58, 3, 33, 123],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13, 15],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13, 15, 138],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13, 15, 138, 34],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13, 15, 138, 34, 139],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13, 15, 138, 34, 139, 35],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13, 15, 138, 34, 139, 35, 47],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13, 15, 138, 34, 139, 35, 47, 26],
#  [137, 1, 137, 215, 58, 3, 33, 123, 14, 13, 15, 138, 34, 139, 35, 47, 26, 10],
#  [137,
#   1,
#   137,
#   215,
#   58,
#   3,
#   33,
#   123,
#   14,
#   13,
#   15,
#   138,
#   34,
#   139,
#   35,
#   47,
#   26,
#   10,
#   39],
#  [137,
#   1,
#   137,
#   215,
#   58,
#   3,
#   33,
#   123,
#   14,
#   13,
#   15,
#   138,
#   34,
#   139,
#   35,
#   47,
#   26,
#   10,
#   39,
#   3],
#  [137,
#   1,
#   137,
#   215,
#   58,
#   3,
#   33,
#   123,
#   14,
#   13,
#   15,
#   138,
#   34,
#   139,
#   35,
#   47,
#   26,
#   10,
#   39,
#   3,
#   33],
#  [137,
#   1,
#   137,
#   215,
#   58,
#   3,
#   33,
#   123,
#   14,
#   13,
#   15,
#   138,
#   34,
#   139,
#   35,
#   47,
#   26,
#   10,
#   39,
#   3,
#   33,
#   216],
#  [137,
#   1,
#   137,
#   215,
#   58,
#   3,
#   33,
#   123,
#   14,
#   13,
#   15,
#   138,
#   34,
#   139,
#   35,
#   47,
#   26,
#   10,
#   39,
#   3,
#   33,
#   216,
#   2],
#  [137,
#   1,
#   137,
#   215,
#   58,
#   3,
#   33,
#   123,
#   14,
#   13,
#   15,
#   138,
#   34,
#   139,
#   35,
#   47,
#   26,
#   10,
#   39,
#   3,
#   33,
#   216,
#   2,
#   217],
#  [137,
#   1,
#   137,
#   215,
#   58,
#   3,
#   33,
#   123,
#   14,
#   13,
#   15,
#   138,
#   34,
#   139,
#   35,
#   47,
#   26,
#   10,
#   39,
#   3,
#   33,
#   216,
#   2,
#   217,
#   14],
#  [60, 92],
#  [60, 92, 40],
#  [60, 92, 40, 41],
#  [60, 92, 40, 41, 4],
#  [60, 92, 40, 41, 4, 41],
#  [60, 92, 40, 41, 4, 41, 21],
#  [60, 92, 40, 41, 4, 41, 21, 6],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5, 218],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5, 218, 2],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5, 218, 2, 61],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5, 218, 2, 61, 11],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5, 218, 2, 61, 11, 62],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5, 218, 2, 61, 11, 62, 34],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5, 218, 2, 61, 11, 62, 34, 35],
#  [60, 92, 40, 41, 4, 41, 21, 6, 140, 93, 5, 218, 2, 61, 11, 62, 34, 35, 26],
#  [60,
#   92,
#   40,
#   41,
#   4,
#   41,
#   21,
#   6,
#   140,
#   93,
#   5,
#   218,
#   2,
#   61,
#   11,
#   62,
#   34,
#   35,
#   26,
#   10],
#  [60,
#   92,
#   40,
#   41,
#   4,
#   41,
#   21,
#   6,
#   140,
#   93,
#   5,
#   218,
#   2,
#   61,
#   11,
#   62,
#   34,
#   35,
#   26,
#   10,
#   39],
#  [60,
#   92,
#   40,
#   41,
#   4,
#   41,
#   21,
#   6,
#   140,
#   93,
#   5,
#   218,
#   2,
#   61,
#   11,
#   62,
#   34,
#   35,
#   26,
#   10,
#   39,
#   3],
#  [60,
#   92,
#   40,
#   41,
#   4,
#   41,
#   21,
#   6,
#   140,
#   93,
#   5,
#   218,
#   2,
#   61,
#   11,
#   62,
#   34,
#   35,
#   26,
#   10,
#   39,
#   3,
#   33],
#  [60,
#   92,
#   40,
#   41,
#   4,
#   41,
#   21,
#   6,
#   140,
#   93,
#   5,
#   218,
#   2,
#   61,
#   11,
#   62,
#   34,
#   35,
#   26,
#   10,
#   39,
#   3,
#   33,
#   48],
#  [60,
#   92,
#   40,
#   41,
#   4,
#   41,
#   21,
#   6,
#   140,
#   93,
#   5,
#   218,
#   2,
#   61,
#   11,
#   62,
#   34,
#   35,
#   26,
#   10,
#   39,
#   3,
#   33,
#   48,
#   2],
#  [60,
#   92,
#   40,
#   41,
#   4,
#   41,
#   21,
#   6,
#   140,
#   93,
#   5,
#   218,
#   2,
#   61,
#   11,
#   62,
#   34,
#   35,
#   26,
#   10,
#   39,
#   3,
#   33,
#   48,
#   2,
#   94],
#  [60,
#   92,
#   40,
#   41,
#   4,
#   41,
#   21,
#   6,
#   140,
#   93,
#   5,
#   218,
#   2,
#   61,
#   11,
#   62,
#   34,
#   35,
#   26,
#   10,
#   39,
#   3,
#   33,
#   48,
#   2,
#   94,
#   14],
#  [141, 142],
#  [141, 142, 1],
#  [141, 142, 1, 21],
#  [141, 142, 1, 21, 219],
#  [141, 142, 1, 21, 219, 141],
#  [141, 142, 1, 21, 219, 141, 142],
#  [141, 142, 1, 21, 219, 141, 142, 220],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10, 39],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10, 39, 3],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10, 39, 3, 33],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10, 39, 3, 33, 14],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10, 39, 3, 33, 14, 13],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10, 39, 3, 33, 14, 13, 15],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10, 39, 3, 33, 14, 13, 15, 221],
#  [141, 142, 1, 21, 219, 141, 142, 220, 26, 10, 39, 3, 33, 14, 13, 15, 221, 95],
#  [141,
#   142,
#   1,
#   21,
#   219,
#   141,
#   142,
#   220,
#   26,
#   10,
#   39,
#   3,
#   33,
#   14,
#   13,
#   15,
#   221,
#   95,
#   2],
#  [141,
#   142,
#   1,
#   21,
#   219,
#   141,
#   142,
#   220,
#   26,
#   10,
#   39,
#   3,
#   33,
#   14,
#   13,
#   15,
#   221,
#   95,
#   2,
#   222],
#  [141,
#   142,
#   1,
#   21,
#   219,
#   141,
#   142,
#   220,
#   26,
#   10,
#   39,
#   3,
#   33,
#   14,
#   13,
#   15,
#   221,
#   95,
#   2,
#   222,
#   223],
#  [143, 1],
#  [143, 1, 8],
#  [143, 1, 8, 6],
#  [143, 1, 8, 6, 224],
#  [143, 1, 8, 6, 224, 2],
#  [143, 1, 8, 6, 224, 2, 144],
#  [143, 1, 8, 6, 224, 2, 144, 7],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225, 145],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225, 145, 11],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225, 145, 11, 6],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225, 145, 11, 6, 93],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225, 145, 11, 6, 93, 5],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225, 145, 11, 6, 93, 5, 22],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225, 145, 11, 6, 93, 5, 22, 2],
#  [143, 1, 8, 6, 224, 2, 144, 7, 9, 13, 8, 225, 145, 11, 6, 93, 5, 22, 2, 8],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1,
#   7],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1,
#   7,
#   9],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1,
#   7,
#   9,
#   233],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1,
#   7,
#   9,
#   233,
#   45],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1,
#   7,
#   9,
#   233,
#   45,
#   234],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1,
#   7,
#   9,
#   233,
#   45,
#   234,
#   2],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1,
#   7,
#   9,
#   233,
#   45,
#   234,
#   2,
#   235],
#  [143,
#   1,
#   8,
#   6,
#   224,
#   2,
#   144,
#   7,
#   9,
#   13,
#   8,
#   225,
#   145,
#   11,
#   6,
#   93,
#   5,
#   22,
#   2,
#   8,
#   146,
#   226,
#   11,
#   63,
#   30,
#   16,
#   20,
#   7,
#   2,
#   77,
#   16,
#   78,
#   96,
#   97,
#   49,
#   227,
#   3,
#   98,
#   1,
#   228,
#   49,
#   15,
#   229,
#   12,
#   230,
#   1,
#   231,
#   21,
#   6,
#   232,
#   114,
#   3,
#   4,
#   1,
#   7,
#   9,
#   233,
#   45,
#   234,
#   2,
#   235,
#   236],
#  [1, 8],
#  [1, 8, 6],
#  [1, 8, 6, 237],
#  [1, 8, 6, 237, 16],
#  [1, 8, 6, 237, 16, 9],
#  [1, 8, 6, 237, 16, 9, 238],
#  [1, 8, 6, 237, 16, 9, 238, 10],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5, 7],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5, 7, 30],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5, 7, 30, 16],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5, 7, 30, 16, 82],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5, 7, 30, 16, 82, 147],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5, 7, 30, 16, 82, 147, 2],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5, 7, 30, 16, 82, 147, 2, 240],
#  [1, 8, 6, 237, 16, 9, 238, 10, 4, 239, 5, 7, 30, 16, 82, 147, 2, 240, 241],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245,
#   5],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245,
#   5,
#   63],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245,
#   5,
#   63,
#   1],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245,
#   5,
#   63,
#   1,
#   2],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245,
#   5,
#   63,
#   1,
#   2,
#   1],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245,
#   5,
#   63,
#   1,
#   2,
#   1,
#   37],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245,
#   5,
#   63,
#   1,
#   2,
#   1,
#   37,
#   4],
#  [1,
#   8,
#   6,
#   237,
#   16,
#   9,
#   238,
#   10,
#   4,
#   239,
#   5,
#   7,
#   30,
#   16,
#   82,
#   147,
#   2,
#   240,
#   241,
#   16,
#   22,
#   131,
#   242,
#   130,
#   243,
#   36,
#   4,
#   244,
#   50,
#   2,
#   14,
#   245,
#   5,
#   63,
#   1,
#   2,
#   1,
#   37,
#   4,
#   127],
#  [38, 5],
#  [38, 5, 4],
#  [38, 5, 4, 28],
#  [38, 5, 4, 28, 44],
#  [38, 5, 4, 28, 44, 64],
#  [38, 5, 4, 28, 44, 64, 3],
#  [38, 5, 4, 28, 44, 64, 3, 246],
#  [38, 5, 4, 28, 44, 64, 3, 246, 99],
#  [38, 5, 4, 28, 44, 64, 3, 246, 99, 4],
#  [38, 5, 4, 28, 44, 64, 3, 246, 99, 4, 7],
#  [38, 5, 4, 28, 44, 64, 3, 246, 99, 4, 7, 9],
#  [38, 5, 4, 28, 44, 64, 3, 246, 99, 4, 7, 9, 37],
#  [38, 5, 4, 28, 44, 64, 3, 246, 99, 4, 7, 9, 37, 25],
#  [38, 5, 4, 28, 44, 64, 3, 246, 99, 4, 7, 9, 37, 25, 247],
#  [148, 10],
#  [148, 10, 8],
#  [148, 10, 8, 6],
#  [148, 10, 8, 6, 148],
#  [148, 10, 8, 6, 148, 9],
#  [148, 10, 8, 6, 148, 9, 12],
#  [148, 10, 8, 6, 148, 9, 12, 4],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13, 51],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13, 51, 15],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13, 51, 15, 24],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13, 51, 15, 24, 249],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13, 51, 15, 24, 249, 250],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13, 51, 15, 24, 249, 250, 100],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13, 51, 15, 24, 249, 250, 100, 251],
#  [148, 10, 8, 6, 148, 9, 12, 4, 248, 13, 51, 15, 24, 249, 250, 100, 251, 252],
#  [148,
#   10,
#   8,
#   6,
#   148,
#   9,
#   12,
#   4,
#   248,
#   13,
#   51,
#   15,
#   24,
#   249,
#   250,
#   100,
#   251,
#   252,
#   2],
#  [148,
#   10,
#   8,
#   6,
#   148,
#   9,
#   12,
#   4,
#   248,
#   13,
#   51,
#   15,
#   24,
#   249,
#   250,
#   100,
#   251,
#   252,
#   2,
#   253],
#  [148,
#   10,
#   8,
#   6,
#   148,
#   9,
#   12,
#   4,
#   248,
#   13,
#   51,
#   15,
#   24,
#   249,
#   250,
#   100,
#   251,
#   252,
#   2,
#   253,
#   31],
#  [148,
#   10,
#   8,
#   6,
#   148,
#   9,
#   12,
#   4,
#   248,
#   13,
#   51,
#   15,
#   24,
#   249,
#   250,
#   100,
#   251,
#   252,
#   2,
#   253,
#   31,
#   6],
#  [148,
#   10,
#   8,
#   6,
#   148,
#   9,
#   12,
#   4,
#   248,
#   13,
#   51,
#   15,
# ...
#   6,
#   144,
#   9],
#  [174,
#   66,
#   322,
#   1,
#   15,
#   24,
#   23,
#   2,
#   68,
#   53,
#   323,
#   324,
#   325,
#   149,
#   326,
#   2,
#   101,
#   26,
#   10,
#   6,
#   144,
#   9,
#   11],
#  [174,
#   66,
#   322,
#   1,
#   15,
#   24,
#   23,
#   2,
#   68,
#   53,
#   323,
#   324,
#   325,
#   149,
#   326,
#   2,
#   101,
#   26,
#   10,
#   6,
#   144,
#   9,
#   11,
#   81],
#  [174,
#   66,
#   322,
#   1,
#   15,
#   24,
#   23,
#   2,
#   68,
#   53,
#   323,
#   324,
#   325,
#   149,
#   326,
#   2,
#   101,
#   26,
#   10,
#   6,
#   144,
#   9,
#   11,
#   81,
#   174],
#  [174,
#   66,
#   322,
#   1,
#   15,
#   24,
#   23,
#   2,
#   68,
#   53,
#   323,
#   324,
#   325,
#   149,
#   326,
#   2,
#   101,
#   26,
#   10,
#   6,
#   144,
#   9,
#   11,
#   81,
#   174,
#   66],
#  [174,
#   66,
#   322,
#   1,
#   15,
#   24,
#   23,
#   2,
#   68,
#   53,
#   323,
#   324,
#   325,
#   149,
#   326,
#   2,
#   101,
#   26,
#   10,
#   6,
#   144,
#   9,
#   11,
#   81,
#   174,
#   66,
#   22],
#  [112, 1],
#  [112, 1, 8],
#  [112, 1, 8, 6],
#  [112, 1, 8, 6, 23],
#  [112, 1, 8, 6, 23, 9],
#  [112, 1, 8, 6, 23, 9, 17],
#  [112, 1, 8, 6, 23, 9, 17, 75],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8, 327],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8, 327, 100],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8, 327, 100, 52],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8, 327, 100, 52, 14],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8, 327, 100, 52, 14, 328],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8, 327, 100, 52, 14, 328, 10],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8, 327, 100, 52, 14, 328, 10, 8],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 14, 8, 327, 100, 52, 14, 328, 10, 8, 329],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2,
#   332],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2,
#   332,
#   112],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2,
#   332,
#   112,
#   333],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2,
#   332,
#   112,
#   333,
#   3],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2,
#   332,
#   112,
#   333,
#   3,
#   334],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2,
#   332,
#   112,
#   333,
#   3,
#   334,
#   71],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2,
#   332,
#   112,
#   333,
#   3,
#   334,
#   71,
#   109],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   14,
#   8,
#   327,
#   100,
#   52,
#   14,
#   328,
#   10,
#   8,
#   329,
#   54,
#   15,
#   175,
#   12,
#   330,
#   70,
#   331,
#   2,
#   332,
#   112,
#   333,
#   3,
#   334,
#   71,
#   109,
#   335],
#  [55, 176],
#  [55, 176, 1],
#  [55, 176, 1, 336],
#  [55, 176, 1, 336, 337],
#  [55, 176, 1, 336, 337, 55],
#  [55, 176, 1, 336, 337, 55, 176],
#  [55, 176, 1, 336, 337, 55, 176, 17],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15, 177],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15, 177, 3],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15, 177, 3, 95],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15, 177, 3, 95, 97],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15, 177, 3, 95, 97, 67],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15, 177, 3, 95, 97, 67, 338],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15, 177, 3, 95, 97, 67, 338, 339],
#  [55, 176, 1, 336, 337, 55, 176, 17, 15, 177, 3, 95, 97, 67, 338, 339, 102],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113,
#   2],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113,
#   2,
#   15],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113,
#   2,
#   15,
#   175],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113,
#   2,
#   15,
#   175,
#   12],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113,
#   2,
#   15,
#   175,
#   12,
#   76],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113,
#   2,
#   15,
#   175,
#   12,
#   76,
#   48],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113,
#   2,
#   15,
#   175,
#   12,
#   76,
#   48,
#   55],
#  [55,
#   176,
#   1,
#   336,
#   337,
#   55,
#   176,
#   17,
#   15,
#   177,
#   3,
#   95,
#   97,
#   67,
#   338,
#   339,
#   102,
#   54,
#   84,
#   21,
#   76,
#   163,
#   340,
#   4,
#   341,
#   55,
#   113,
#   2,
#   15,
#   175,
#   12,
#   76,
#   48,
#   55,
#   113],
#  [50, 1],
#  [50, 1, 31],
#  [50, 1, 31, 6],
#  [50, 1, 31, 6, 86],
#  [50, 1, 31, 6, 86, 50],
#  [50, 1, 31, 6, 86, 50, 13],
#  [50, 1, 31, 6, 86, 50, 13, 15],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3, 98],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3, 98, 178],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3, 98, 178, 11],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3, 98, 178, 11, 179],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3, 98, 178, 11, 179, 102],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3, 98, 178, 11, 179, 102, 34],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3, 98, 178, 11, 179, 102, 34, 342],
#  [50, 1, 31, 6, 86, 50, 13, 15, 24, 74, 3, 98, 178, 11, 179, 102, 34, 342, 2],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343,
#   10],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343,
#   10,
#   165],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343,
#   10,
#   165,
#   39],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343,
#   10,
#   165,
#   39,
#   3],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343,
#   10,
#   165,
#   39,
#   3,
#   344],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343,
#   10,
#   165,
#   39,
#   3,
#   344,
#   2],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343,
#   10,
#   165,
#   39,
#   3,
#   344,
#   2,
#   138],
#  [50,
#   1,
#   31,
#   6,
#   86,
#   50,
#   13,
#   15,
#   24,
#   74,
#   3,
#   98,
#   178,
#   11,
#   179,
#   102,
#   34,
#   342,
#   2,
#   343,
#   10,
#   165,
#   39,
#   3,
#   344,
#   2,
#   138,
#   34],
#  [91, 37],
#  [91, 37, 38],
#  [91, 37, 38, 5],
#  [91, 37, 38, 5, 4],
#  [91, 37, 38, 5, 4, 44],
#  [91, 37, 38, 5, 4, 44, 64],
#  [91, 37, 38, 5, 4, 44, 64, 3],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168, 345],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168, 345, 62],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168, 345, 62, 34],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168, 345, 62, 34, 1],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168, 345, 62, 34, 1, 27],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168, 345, 62, 34, 1, 27, 346],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168, 345, 62, 34, 1, 27, 346, 91],
#  [91, 37, 38, 5, 4, 44, 64, 3, 167, 12, 168, 345, 62, 34, 1, 27, 346, 91, 180],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347,
#   348],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347,
#   348,
#   2],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347,
#   348,
#   2,
#   33],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347,
#   348,
#   2,
#   33,
#   94],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347,
#   348,
#   2,
#   33,
#   94,
#   14],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347,
#   348,
#   2,
#   33,
#   94,
#   14,
#   12],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347,
#   348,
#   2,
#   33,
#   94,
#   14,
#   12,
#   54],
#  [91,
#   37,
#   38,
#   5,
#   4,
#   44,
#   64,
#   3,
#   167,
#   12,
#   168,
#   345,
#   62,
#   34,
#   1,
#   27,
#   346,
#   91,
#   180,
#   49,
#   15,
#   73,
#   347,
#   348,
#   2,
#   33,
#   94,
#   14,
#   12,
#   54,
#   9],
#  [22, 5],
#  [22, 5, 1],
#  [1, 349],
#  [1, 349, 350],
#  [1, 349, 350, 113],
#  [1, 349, 350, 113, 12],
#  [1, 349, 350, 113, 12, 22],
#  [1, 349, 350, 113, 12, 22, 157],
#  [1, 349, 350, 113, 12, 22, 157, 25],
#  [125, 46],
#  [125, 46, 46],
#  [125, 46, 46, 7],
#  [125, 46, 46, 7, 105],
#  [125, 46, 46, 7, 105, 154],
#  [125, 46, 46, 7, 105, 154, 101],
#  [125, 46, 46, 7, 105, 154, 101, 351],
#  [125, 46, 46, 7, 105, 154, 101, 351, 352],
#  [125, 46, 46, 7, 105, 154, 101, 351, 352, 353],
#  [125, 46, 46, 7, 105, 154, 101, 351, 352, 353, 36],
#  [354, 355],
#  [354, 355, 356],
#  [357, 153],
#  [357, 153, 103],
#  [357, 153, 103, 152],
#  [357, 153, 103, 152, 358],
#  [357, 153, 103, 152, 358, 359],
#  [357, 153, 103, 152, 358, 359, 360],
#  [361, 103],
#  [361, 103, 362],
#  [361, 103, 362, 363],
#  [361, 103, 362, 363, 364],
#  [361, 103, 362, 363, 364, 36],
#  [365, 366],
#  [365, 366, 46],
#  [367, 5],
#  [367, 5, 1],
#  [112, 1],
#  [112, 1, 8],
#  [112, 1, 8, 6],
#  [112, 1, 8, 6, 23],
#  [112, 1, 8, 6, 23, 9],
#  [112, 1, 8, 6, 23, 9, 17],
#  [112, 1, 8, 6, 23, 9, 17, 75],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14, 8],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14, 8, 23],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14, 8, 23, 100],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14, 8, 23, 100, 52],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14, 8, 23, 100, 52, 368],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14, 8, 23, 100, 52, 368, 14],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14, 8, 23, 100, 52, 368, 14, 26],
#  [112, 1, 8, 6, 23, 9, 17, 75, 13, 45, 14, 8, 23, 100, 52, 368, 14, 26, 10],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   45,
#   14,
#   8,
#   23,
#   100,
#   52,
#   368,
#   14,
#   26,
#   10,
#   43],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   45,
#   14,
#   8,
#   23,
#   100,
#   52,
#   368,
#   14,
#   26,
#   10,
#   43,
#   5],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   45,
#   14,
#   8,
#   23,
#   100,
#   52,
#   368,
#   14,
#   26,
#   10,
#   43,
#   5,
#   4],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   45,
#   14,
#   8,
#   23,
#   100,
#   52,
#   368,
#   14,
#   26,
#   10,
#   43,
#   5,
#   4,
#   369],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   45,
#   14,
#   8,
#   23,
#   100,
#   52,
#   368,
#   14,
#   26,
#   10,
#   43,
#   5,
#   4,
#   369,
#   7],
#  [112,
#   1,
#   8,
#   6,
#   23,
#   9,
#   17,
#   75,
#   13,
#   45,
#   14,
#   8,
#   23,
#   100,
#   52,
#   368,
#   14,
#   26,
#   10,
#   43,
#   5,
#   4,
#   369,
#   7,
#   71],
#  [18, 19],
#  [18, 19, 7],
#  [18, 19, 7, 1],
#  [18, 19, 7, 1, 56],
#  [18, 19, 7, 1, 56, 18],
#  [18, 19, 7, 1, 56, 18, 19],
#  [18, 19, 7, 1, 56, 18, 19, 7],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10, 39],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10, 39, 3],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10, 39, 3, 33],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10, 39, 3, 33, 2],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10, 39, 3, 33, 2, 111],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10, 39, 3, 33, 2, 111, 32],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10, 39, 3, 33, 2, 111, 32, 86],
#  [18, 19, 7, 1, 56, 18, 19, 7, 17, 172, 10, 39, 3, 33, 2, 111, 32, 86, 22],
#  [60, 92],
#  [60, 92, 40],
#  [60, 92, 40, 41],
#  ...]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:, -1]

# %%
X.shape
# Out:
# (1285, 63)

# %%
y.shape
# Out:
# (1285,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes=len(tokenizer.word_index)+1)

# %%
y.shape
# Out:
# (1285, 449)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(449, 100, input_length = 63))
model.add(LSTM(150))
model.add(Dense(449, activation = 'softmax'))

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, y, epochs =100)
# Out:
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.0257 - loss: 5.9703
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0493 - loss: 5.3964
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0633 - loss: 5.2773
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0570 - loss: 5.2835
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0638 - loss: 5.1616
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0758 - loss: 5.0431
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1069 - loss: 4.7985
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1181 - loss: 4.5871
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1492 - loss: 4.4783
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1934 - loss: 4.1795
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2287 - loss: 3.9420
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2371 - loss: 3.6868
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2989 - loss: 3.4861
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3311 - loss: 3.2546
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3647 - loss: 3.0240
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3647 - loss: 2.8874
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4239 - loss: 2.6248
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4676 - loss: 2.4786
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5033 - loss: 2.2860
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5439 - loss: 2.1727
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6027 - loss: 1.9486
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6278 - loss: 1.8593
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7034 - loss: 1.6772
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7190 - loss: 1.5537
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7452 - loss: 1.4685
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8057 - loss: 1.2853
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8122 - loss: 1.2202
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8477 - loss: 1.0960
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8613 - loss: 1.0261
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8664 - loss: 0.9317
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8764 - loss: 0.8796
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9029 - loss: 0.7927
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9202 - loss: 0.7151
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9418 - loss: 0.6442
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9398 - loss: 0.5892
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9362 - loss: 0.5852
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9555 - loss: 0.5320
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9616 - loss: 0.4671
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9603 - loss: 0.4556
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9601 - loss: 0.4358
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9674 - loss: 0.3997
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9641 - loss: 0.3793
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9725 - loss: 0.3586
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9756 - loss: 0.3278
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9708 - loss: 0.3035
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9832 - loss: 0.2767
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9823 - loss: 0.2728
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9808 - loss: 0.2502
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9774 - loss: 0.2443
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9768 - loss: 0.2302
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9734 - loss: 0.2188
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9833 - loss: 0.1986
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9732 - loss: 0.2032
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9854 - loss: 0.1978
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9826 - loss: 0.1821
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9836 - loss: 0.1681
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9868 - loss: 0.1545
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9839 - loss: 0.1606
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9853 - loss: 0.1501
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9820 - loss: 0.1430
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9830 - loss: 0.1397
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9909 - loss: 0.1187
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9815 - loss: 0.1305
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9784 - loss: 0.1282
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9756 - loss: 0.1273
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9826 - loss: 0.1214
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9842 - loss: 0.1197
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9865 - loss: 0.1039
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9845 - loss: 0.1073
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9832 - loss: 0.1012
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9877 - loss: 0.0961
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9841 - loss: 0.0978
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9833 - loss: 0.0989
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9831 - loss: 0.0888
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9886 - loss: 0.0790
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9755 - loss: 0.1009
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9891 - loss: 0.0822
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9865 - loss: 0.0807
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9891 - loss: 0.0744
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9875 - loss: 0.0749
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9835 - loss: 0.0696
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9907 - loss: 0.0615
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9849 - loss: 0.0718
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9930 - loss: 0.0612
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9860 - loss: 0.0757
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9780 - loss: 0.0718
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9857 - loss: 0.0689
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9820 - loss: 0.0680
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9855 - loss: 0.0599
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0570
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 0.0572
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 0.0580
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9830 - loss: 0.0638
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9890 - loss: 0.0519
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9840 - loss: 0.0546
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.0565
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9768 - loss: 0.0603
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9848 - loss: 0.0538
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9884 - loss: 0.0509
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9757 - loss: 0.0614

# %%
import numpy as np
text = "c++ is a"

for i in range(10):
  #tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  #padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  #predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# c++ is a general
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# c++ is a general purpose
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# c++ is a general purpose programming
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# c++ is a general purpose programming language
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# c++ is a general purpose programming language that
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# c++ is a general purpose programming language that was
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# c++ is a general purpose programming language that was developed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# c++ is a general purpose programming language that was developed as
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# c++ is a general purpose programming language that was developed as an
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# c++ is a general purpose programming language that was developed as an enhancement
